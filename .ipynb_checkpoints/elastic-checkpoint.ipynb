# %%
from elasticsearch import Elasticsearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth

host = 'search-trial-cc4abhfofwbjogy5nla5sndexq.us-west-2.es.amazonaws.com'
awsauth = AWS4Auth('AKIAJQ5JJZM5HDDOMTNQ', 'uVqOuxD+e/iaLkfusHi4TgO1wqrSdUsz2I+VLoAS', 'us-west-2', 'es')

es = Elasticsearch(
    hosts=[{'host': host, 'port': 443}],
    http_auth=awsauth,
    use_ssl=True,
    verify_certs=True,
    connection_class=RequestsHttpConnection
)
print(es.info())
# Out:
# {'version': {'build_timestamp': '2015-04-27T09:21:06Z', 'number': '1.5.2', 'build_hash': '62ff9868b4c8a0c45860bebb259e21980778ab1c', 'lucene_version': '4.10.4', 'build_snapshot': False}, 'tagline': 'You Know, for Search', 'name': 'Crimson and the Raven', 'status': 200, 'cluster_name': '275592502545:trial'}

# %% [markdown]
# ## PS DF

# %%
##PS_DF CSV
import csv
import urllib3
f = open(raw_data_path+csv_filename)
csv_file_object = csv.reader(f)
    
header = list(df.columns)
header = [item.lower() for item in header]
INDEX_NAME = 'weiboscope'
TYPE_NAME = 'tweet'

bulk_data = [] 

for row in df.iterrows():
    data_dict = {}
    for i in range(len(row[1])):
        data_dict[header[i]] = row[1][i]
    op_dict = {
        "index": {
            "_index": INDEX_NAME, 
            "_type": TYPE_NAME, 
#             "_id": data_dict[ID_FIELD]
        }
    }
    bulk_data.append(op_dict)
    bulk_data.append(data_dict)

# %%
from elasticsearch import helpers

# %%
try :
    es.indices.delete(index=INDEX_NAME)
except :
    pass

es.indices.create(index=INDEX_NAME)

es.bulk(index = INDEX_NAME, body = bulk_data,timeout=1000)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\Users\kennd\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# C:\Users\kennd\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     361         else:
# --> 362             conn.request(method, url, **httplib_request_kw)
#     363
#
# C:\Users\kennd\Anaconda3\lib\http\client.py in request(self, method, url, body, headers)
#    1082         """Send a complete request to the server."""
# ...

# %%
bulk = []

# %%
bulk.append((op_dict,data_dict))

# %%
df = pd.read_json('C:/Users/kennd/Documents/GitHub/kcs_app/ps_df.json').reset_index(drop=True)

# %% [markdown]
# ## PS DF Bulk Helper

# %%
df = pd.read_json('C:/Users/kennd/Documents/GitHub/kcs_app/processed_df.json')

# %%
df2 = df.iloc[0:1000,:]

# %%
##PS_DF CSV
    
header = list(df.columns)
header = [item.lower() for item in header]
INDEX_NAME = 'weiboscope'
TYPE_NAME = 'tweet'

bulk_data = [] 
index = 0
for row in df.iterrows():
    index += 1
    data_dict = {}
    for i in range(len(row[1])):
        data_dict[header[i]] = row[1][i]
    op_dict = {
            "_index": INDEX_NAME, 
            "_type": TYPE_NAME, 
            "_id": index,
            "_source": data_dict
        }
    bulk_data.append(op_dict)

# %%
try :
    es.indices.delete(index=INDEX_NAME)
except :
    pass

es.indices.create(index=INDEX_NAME)

helpers.bulk(es,bulk_data,timeout=30,chunk_size=200)
# Out:
# (10411, [])

# %%
matches = es.search(index='weiboscope', q='food', size=100)
hits = matches['hits']['hits']

# %%
pd.DataFrame(list(pd.DataFrame(hits)['_source']))
# Out:
#                                               article  \
# 0   New York – Lack of food is rarely the reason p...
# 1   ROME – Lack of food is rarely the reason that ...
# 2   NEW YORK – Had you told me a year ago that I w...
# 3   A fundamental global trend nowadays is growing...
# 4   LONDON – With food prices having doubled in th...
# 5   COPENHAGEN\r  – \r The global food system is i...
# 6   NEW YORK – Food systems have gone global. The ...
# 7   GENEVA – The recent sharp spike in food prices...
# 8   PARIS – The world has been shaken by unprecede...
# 9   ROME – Every year, we waste or lose 1.3 billio...
# 10  SINGAPORE – According to current estimates, In...
# 11  STANFORD – During the late 1990’s, a singular ...
# 12  BRUSSELS – What should the G-20 do to prepare ...
# 13  BRUSSELS – There are plenty of summits to choo...
# 14  Niger’s food emergency has reached the world’s...
# 15  OTTAWA – One-quarter of all the food in the wo...
# ...

# %%
# Out:
#   File "<ipython-input-215-bf7b7bbb961e>", line 1
#     es.
#        ^
# SyntaxError: invalid syntax
